# %%
import re

def remove_emoji(text):
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"
        u"\U0001F300-\U0001F5FF"
        u"\U0001F680-\U0001F6FF"
        u"\U0001F1E0-\U0001F1FF"
        "]+",
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# %%
import pandas as pd
data=pd.read_csv('emoji_removal_dataset.csv')
data
# Out:
#                original_text       text_without_emoji
# 0          I am very happy 😊          I am very happy
# 1         This is amazing 🔥🔥          This is amazing
# 2        Feeling sad today 😢        Feeling sad today
# 3             I love NLP ❤️🤖               I love NLP
# 4    Good morning 🌅 everyone    Good morning everyone
# 5  This project is awesome 😎  This project is awesome
# 6  Machine learning is fun 🤩  Machine learning is fun
# 7  I am tired 😴 after coding  I am tired after coding
# 8     Great job 👍 keep it up     Great job keep it up
# 9      Python is powerful 🐍💻       Python is powerful

# %%
data['original_text']
# Out:
# 0            I am very happy 😊
# 1           This is amazing 🔥🔥
# 2          Feeling sad today 😢
# 3               I love NLP ❤️🤖
# 4      Good morning 🌅 everyone
# 5    This project is awesome 😎
# 6    Machine learning is fun 🤩
# 7    I am tired 😴 after coding
# 8       Great job 👍 keep it up
# 9        Python is powerful 🐍💻
# Name: original_text, dtype: object

# %%
data['original_text'].apply(remove_emoji)
# Out:
# 0             I am very happy
# 1             This is amazing
# 2           Feeling sad today
# 3               I love NLP ❤️🤖
# 4       Good morning  everyone
# 5     This project is awesome
# 6    Machine learning is fun 🤩
# 7     I am tired  after coding
# 8        Great job  keep it up
# 9          Python is powerful
# Name: original_text, dtype: object

# %%
data['original_text']=data['original_text'].apply(remove_emoji)

# %%
data
# Out:
#                original_text       text_without_emoji
# 0           I am very happy           I am very happy
# 1           This is amazing           This is amazing
# 2         Feeling sad today         Feeling sad today
# 3             I love NLP ❤️🤖               I love NLP
# 4     Good morning  everyone    Good morning everyone
# 5   This project is awesome   This project is awesome
# 6  Machine learning is fun 🤩  Machine learning is fun
# 7   I am tired  after coding  I am tired after coding
# 8      Great job  keep it up     Great job keep it up
# 9        Python is powerful        Python is powerful
