# %%
import pandas as pd

# %%
data=pd.read_csv('sample_text_dataset.csv')

# %%
data.head()
# Out:
#    id                            text
# 0   1         I LOVE Machine Learning
# 1   2     NLP is AMAZING and Powerful
# 2   3     Python Is The BEST Language
# 3   4     This COURSE is Very Helpful
# 4   5  DATA Science and AI Are Future

# %%
data['text']
# Out:
# 0           I LOVE Machine Learning
# 1       NLP is AMAZING and Powerful
# 2       Python Is The BEST Language
# 3       This COURSE is Very Helpful
# 4    DATA Science and AI Are Future
# Name: text, dtype: object

# %%
data['text'][2].lower()
# Out:
# 'python is the best language'

# %%
data['text'].str.lower()
# Out:
# 0           i love machine learning
# 1       nlp is amazing and powerful
# 2       python is the best language
# 3       this course is very helpful
# 4    data science and ai are future
# Name: text, dtype: object

# %%
data['text']=data['text'].str.lower()

# %%
data.head()
# Out:
#    id                            text
# 0   1         i love machine learning
# 1   2     nlp is amazing and powerful
# 2   3     python is the best language
# 3   4     this course is very helpful
# 4   5  data science and ai are future
